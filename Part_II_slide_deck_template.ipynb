# %% [markdown]
# # Part II - Airline Delay Cause
# ## by Vamshi Krishna Reddy Singireddy

# %% [markdown]
# ## Investigation Overview
#
#
#
#
# The goal is to show the major causes of flight delay. The relation between these reasons was explored. There are outside factors that influence the delay as number of flights can directly impact the air traffic. There shouldn't much difference in frequency of flights unless the routes are stopped due to a business reason or due to external events like a pandemic or economic downturn. We also found there is high correlation between different delay reasons.
#
#
#
#
# ## Dataset Overview
#
# The dataset is maitained by U.S. Department of Transportation with data reported by airlines. The delay reasons reported are carrier, late aircraft, nas (air traffic), weather, and security. There is one record for every airline and airport per month. The other details provided are total flights arriving into airport, cancellations, and divertions.

# %%
# import all packages and set plots to be embedded inline
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sb

# %matplotlib inline

# suppress warnings from final output
import warnings
warnings.simplefilter("ignore")

# %%
# load in the dataset into a pandas dataframe
delay_cause = pd.read_csv('Airline_Delay_Cause.csv')

# %% [markdown]
# ## Correlation between delay reasons
#
# High correlation observed between below delay reasons:
#
# Carrier_delay and late_aircraft_delay has 0.84
#
# Carrier_delay and weather_delay has 0.72
#
# nas_daily and late_aircraft_delay has 0.72

# %% [markdown]
# ![correlation%20heatmap.png](attachment:correlation%20heatmap.png)

# %% [markdown]
# ## Delay caused by various reasons
#
# ### Main reasons for delay in minutes
#
# late_aircraft_delay
#
# carrier_delay
#
# nas_delay
#
#
# ### Main reasons for number of flights delayed
#
# late_aircraft_ct
#
# nas_delay_ct
#
# carrier_ct

# %% [markdown]
# ![Flight%20delay%20mins%20by%20reason.png](attachment:Flight%20delay%20mins%20by%20reason.png)

# %% [markdown]
# ![Flight%20Count%20by%20Delay%20Reason.png](attachment:Flight%20Count%20by%20Delay%20Reason.png)

# %% [markdown]
# ## Relation between flights arrived and delay
#
# Correlation observed between arrived flights and delayed flights
#
# Year 2020 has biggest drop in arrived flights and hence less flights delayed.

# %% [markdown]
# ![ratio%20of%20delay%20flights%20-%20box%20plot%20trend.png](attachment:ratio%20of%20delay%20flights%20-%20box%20plot%20trend.png)

# %% [markdown]
# ![arrived%20vs%20delay%20-regression%20plot.png](attachment:arrived%20vs%20delay%20-regression%20plot.png)

# %% [markdown]
# ![arrived%20vs%20delay%20-regression%20plot-sample%20data.png](attachment:arrived%20vs%20delay%20-regression%20plot-sample%20data.png)

# %%
# !jupyter nbconvert <Part_II_Filename>.ipynb --to slides --post serve --no-input --no-prompt
# Out:
# The system cannot find the file specified.
